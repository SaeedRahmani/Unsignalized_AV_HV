# %%
import os
import tensorflow as tf
from waymo_open_dataset.protos import scenario_pb2
# Out:
# 2025-05-11 22:37:12.885791: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-11 22:37:12.913811: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-11 22:37:12.914698: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-11 22:37:13.499249: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset_directory = "./raw_data/waymo/training_20s/"  # 20s training dataset
all_tfrecord_names = os.listdir(dataset_directory)
all_tfrecord_paths = [dataset_directory + str(name) for name in all_tfrecord_names]

# %%
dataset = tf.data.TFRecordDataset(all_tfrecord_paths[0])

for scenario_index, scenario_proto in enumerate(dataset):
    # convert proto to python object
    scenario = scenario_pb2.Scenario()
    scenario.ParseFromString(scenario_proto.numpy())

    print(scenario.compressed_frame_laser_data)
    break
# Out:
# []
